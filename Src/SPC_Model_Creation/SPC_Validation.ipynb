# %%
import numpy as np
import pandas as pd
import SPC_AD_library as sp

# %%
Test1=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test1)
Test1[5]=10
Test1[10]=-4
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule1(Test1,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1])
sp.plot_chart(Test1, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule1(TestNormal,Limits2[0][0]-Limits2[0][1],Limits2[0][0]+Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test2=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test2)
Test2[5:13]=[1.2,1.5,1.5,1.4,1.9,1.4,1.2, 1.1]
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule2(Test2,Limits[0][0],Limits[0][1])
sp.plot_chart(Test2, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule2(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test3=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test3)
Test3[5:10]=[1.2,1.3,1.4,1.5,1.6]
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule3(Test3,Limits[0][0],Limits[0][1])
sp.plot_chart(Test3, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule3(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test4=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test4)
Test4[5:16]=[1.2,0.1,1.3,0.3,1.3,0.2,1.7,0.2,1.3,-0.1,0.5]
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule4(Test4,Limits[0][0],Limits[0][1])
sp.plot_chart(Test4, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule4(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test5=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test5)
Test5[5]=2.5
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule5(Test5,Limits[0][0],Limits[0][1])
sp.plot_chart(Test5, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule5(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test6=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test6)
Test6[3:6]=[1.5, 1.6, 1.6]
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule6(Test6,Limits[0][0],Limits[0][1])
sp.plot_chart(Test6, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule6(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test7=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test7)
Test7[3:13]=[0.5, 0.6, 0.7,0.2, 0.1, 0.5,0.8, 0.1, 0.6,0.1]
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule7(Test7,Limits[0][0],Limits[0][1])
sp.plot_chart(Test7, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule7(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])

# %%
Test8=np.random.normal(0,1,size=20)
Limits=sp.analyze(Test8)
Test8[3:11]=[2.3,2.6,-2.4,-2.7,2.3,2.6,-2.4,-2.7]
TestNormal=np.random.normal(0,1,size=20)
Limits2=sp.analyze(TestNormal)
Results=sp.rule8(Test8,Limits[0][0],Limits[0][1])
sp.plot_chart(Test8, Results,Limits[0][0]-Limits[0][1],Limits[0][0]+Limits[0][1],Limits[0][0])
Results2=sp.rule8(TestNormal,Limits2[0][0], Limits2[0][1])
sp.plot_chart(TestNormal, Results2,Limits2[0][0]+Limits2[0][1],Limits2[0][0]-Limits2[0][1],Limits2[0][0])
